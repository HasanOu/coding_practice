# %% [markdown]
# 🟢 Beginner String Exercises
#
#     Reverse a string
#     Input: "hello" → Output: "olleh"
#
#     Check for palindrome
#     Input: "madam" → Output: True
#
#     Count vowels in a string
#     Input: "education" → Output: 5
#
#     Remove punctuation from a string
#     Input: "Hello, world!" → Output: "Hello world"
#
#     Capitalize the first letter of each word
#     Input: "this is a test" → Output: "This Is A Test"
#
#     Replace multiple spaces with a single space
#     Input: "This is messy" → Output: "This is messy"
#
#     Find the most frequent character
#     Input: "aabbbccd" → Output: 'b'
#
#     Check if two strings are anagrams
#     Input: "listen", "silent" → Output: True
#
# 🟡 Intermediate String Exercises
#
#     Find the first non-repeating character
#     Input: "swiss" → Output: 'w'
#
#     Convert snake_case to CamelCase
#     Input: "this_is_variable" → Output: "ThisIsVariable"
#
#     Compress repeating characters (Run-length encoding)
#     Input: "aaabbbcc" → Output: "a3b3c2"
#
#     Remove all duplicates but preserve order
#     Input: "abracadabra" → Output: "abrcd"
#
#     Group anagrams
#     Input: ["eat", "tea", "tan", "ate", "nat", "bat"]
#     Output: [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]
#
#     Find the longest common prefix
#     Input: ["flower", "flow", "flight"] → Output: "fl"
#
#     Find all substrings of a string
#     Input: "abc"
#     Output: ["a", "ab", "abc", "b", "bc", "c"]
#
#     Count words, digits, uppercase, and lowercase letters
#     Input: "Hello World 123"
#     Output: Words: 2, Digits: 3, Uppercase: 2, Lowercase: 8
#
#     Parse a log string and extract fields
#     Input: "2023-05-16 08:34:21, INFO, User login: john_doe"
#     Output: date=2023-05-16, level=INFO, user=john_doe
#
# 🔴 Advanced String Exercises
#
#     Implement strStr() (find substring index)
#     Input: haystack = "hello", needle = "ll"
#     Output: 2
#
#     Minimum window substring containing all characters
#     Input: S = "ADOBECODEBANC", T = "ABC"
#     Output: "BANC"
#
#     Check if two strings are isomorphic
#     Input: "egg" and "add"
#     Output: True
#
#     Longest substring without repeating characters
#     Input: "abcabcbb" → Output: "abc"
#
#     Implement a basic regex matcher
#     Supports . and *
#     Input: s = "aab", p = "c*a*b"
#     Output: True
#
#     Zigzag Conversion
#     Input: "PAYPALISHIRING", numRows = 3
#     Output: "PAHNAPLSIIGYIR"
#
#     Valid Parentheses Check
#     Input: "({[]})" → Output: True

# %%
import string
text= "hello"
text[::-1]

text= "madam"
if text==text[::-1]:
    print("Palindrome")

text = "education"
len([chr for chr in text if chr not in 'aiuo'])

text = "Hello, World!"

"".join([chr for chr in text if chr not in string.punctuation])

text= "this is a test"
" ".join([word.capitalize() for word in text.split()])

text = "This    is    messy"
" ".join(text.split())

text = "aabbbccdddd"
from collections import Counter
Counter(text)
max(Counter(text))

from collections import defaultdict
dict=defaultdict(int)
for chr in text:
    dict[chr]+=1

str1 = "listen"
str2 = "silent"
is_anagram = sorted(str1) == sorted(str2)
print(is_anagram)

text = "This_Is_A_Variable"
"".join(text.split("_"))

text = "aaabbccccdddd"
dict_num= Counter(text)


output = ""
seen = set()
for chr in text:
    if chr not in seen:
        output+= chr+str(dict_num[chr])
        seen.add(chr)

print(output)

text = "aabbca"

seen=set()
output = ""
for chr in text:
    if chr not in seen:
        output+=chr
        seen.add(chr)

print(output)

Input = ["eat", "tea", "tan", "ate", "nat", "bat"]
# Output: [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

anagrams = defaultdict(list)
for word in Input:
    key = "".join(sorted(word))
    anagrams[key].append(word)

grouped_anagrams = list(anagrams.values())
print(grouped_anagrams)
anagrams
# Out:
# Palindrome
# True
# a3b2c4d4
# abc
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]
# defaultdict(list,
#             {'aet': ['eat', 'tea', 'ate'],
#              'ant': ['tan', 'nat'],
#              'abt': ['bat']})
